# %% [markdown]
# # - API

# %%
import tmdbsimple as tmdb
import pandas as pd
import os, time,json
import tmdbsimple as tmdb

# %%
with open('/Users/cathe/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
tmdb.API_KEY = login['api-key']

# %%
movie = tmdb.Movies(603)

# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple

# %%
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/oMsxZEvz9a708d49b6UdZK1KAo5.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 81.526,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
# ...

# %%
info['budget']
# Out:
# 63000000

# %%
info['revenue']
# Out:
# 463517383

# %%
info['imdb_id']
# Out:
# 'tt0133093'

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
releases = movie.releases()
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# PG
# PG
# PG

# %%
# Get the movie object for the current id
movie = tmdb.Movies('tt1361336')
# save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()
# Loop through countries in releases
for c in releases['countries']:
    # if the country abbreviation==US
    if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
       info['certification'] = c['certification']

# %%
def get_movie_with_rating(movie_id):
    """Adapted from source = https://github.com/celiao/tmdbsimple"""
    movie = tmdb.Movies(movie_id)
    info = movie.info()
    releases = movie.releases()
    for c in releases['countries']:
        if c['iso_3166_1'] =='US':
            info['certification'] = c['certification']
    return info

# %%
test = get_movie_with_rating("tt0848228") #put your function name here
test
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 140.783,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
# ...

# %%
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except: 
        pass
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
# ...

# %%
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
errors = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except Exception as e: 
        errors.append([movie_id, e])
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
# ...

# %%
print(f"- Number of errors: {len(errors)}")
errors
# Out:
# - Number of errors: 1
# [['tt0115937',
#   requests.exceptions.HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=07528781488d7824283720edbc76a31e')]]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_2000 = pd.read_csv('Data/final_tmdbdata2000.csv.gz')
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2  tt0113092    0.0                               NaN
# 3  tt0116391    0.0                               NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN         NaN
# 1                                                NaN  10000000.0
# 2                                                NaN         0.0
# 3                                                NaN         0.0
# 4  {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# ...

# %%
df_2001 = pd.read_csv('Data/final_tmdbdata2001.csv.gz')
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
df2 = pd.concat((df_2000, df_2001), axis = 1)
df2
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1327        NaN    NaN                               NaN
# 1328        NaN    NaN                               NaN
# 1329        NaN    NaN                               NaN
# 1330        NaN    NaN                               NaN
# 1331        NaN    NaN                               NaN
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN  10000000.0
# 2                                                   NaN         0.0
# ...

# %%
df2.loc[ df2['budget'] > 0 | ['revenue'] > 0 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 df2.loc[ df2['budget'] > 0 |['revenue'] > 0 ]
#
# TypeError: unsupported operand type(s) for |: 'int' and 'list'

# %%
df_merged.loc[ df_merged['revenue'] > 0 ]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 10    tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13    tt0120630    0.0  /xWG7emUlBPhsJ2MyQHqH0poeXwm.jpg
# 16    tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# ...         ...    ...                               ...
# 2385  tt0310149    0.0  /qpI3S8hytJzzp5tuLv1t6b7fZ67.jpg
# 2386  tt0310790    0.0  /hAvu0oWrEbbPN71QC8w1NIoUYQT.jpg
# 2456  tt0355857    0.0  /j8Kjy0jiUv3pr7qlEzZXSJRSv1y.jpg
# 2498  tt0445841    0.0  /lO3XAxV38SC7ZuuNVdy6E6nOZac.jpg
# 2516  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
#
#                                   belongs_to_collection      budget  \
# 4     {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
# 10                                                  NaN         0.0
# 11                                                  NaN    120000.0
# ...

# %%
df_merged.loc[ df_merged['certification'] == "G"]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 13    tt0120630    0.0  /xWG7emUlBPhsJ2MyQHqH0poeXwm.jpg
# 20    tt0120917    0.0  /mZj8EUr6F1x2PWZjKPxaeYd5WRw.jpg
# 24    tt0123055    0.0                               NaN
# 272   tt0192255    0.0  /xiVZGT0kKT5wCy7VaYuf5rr6Fnu.jpg
# 381   tt0205461    0.0  /c4uxjS8iAiNwKzFG2SGBmS0EDlp.jpg
# 416   tt0208298    0.0  /guTKlQh7Na7bec8SoAzSfYQWaUK.jpg
# 445   tt0211181    0.0  /eqZ5t82asfprFcNS56eVruNT5G5.jpg
# 469   tt0213203    0.0  /9yxIBACv6GZs9JrhizDW6SEYaNu.jpg
# 567   tt0220099    0.0  /60JMvMGuLHSlVjoUpi86UiB5Lmq.jpg
# 694   tt0235679    0.0  /6X3qdsHcwu06GiiXwwNRWzfJ5oJ.jpg
# 948   tt0263118    0.0                               NaN
# 1015  tt0270560    0.0  /xnOUkH3RcAKDajBIXLuntiPkkO8.jpg
# 1087  tt0293854    0.0  /pu4qTZdFaUfXGjepFDw94zMxJs6.jpg
# 1187  tt1291055    0.0  /5KwDfIM7UO2vPXr4E7JEmeiFxwU.jpg
# 1335  tt0198781    0.0  /vUTVUdfbsY4DePCYzxxDMXKp6v6.jpg
# ...

# %%
df_merged.loc[ df_merged['certification'] == "PG"]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 19    tt0120913    0.0  /pniACHS8KDVCldB3BlwL78RIZ7V.jpg
# 22    tt0122459    0.0  /oNOJoW2XoH3shkQxHtOyacJRBCQ.jpg
# 27    tt0130623    0.0  /laeEtakR2pLKu3CeRwB2lU5Y53X.jpg
# 28    tt0131704    0.0  /9K1y8HCokYpuU92jKauiFwu0y7P.jpg
# ...         ...    ...                               ...
# 2233  tt0292996    0.0                               NaN
# 2286  tt0296845    0.0   /HBDCAk7pkHFbanbIsfeElE14x1.jpg
# 2339  tt0302819    0.0                               NaN
# 2386  tt0310790    0.0  /hAvu0oWrEbbPN71QC8w1NIoUYQT.jpg
# 2433  tt0329589    0.0  /ayGKiqIO1leQbt4WXl3aKFxAbdN.jpg
#
#                                   belongs_to_collection       budget  \
# 4     {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...     150000.0
# 19                                                  NaN   75000000.0
# 22                                                  NaN   24000000.0
# ...

# %%
df_merged.loc[ df_merged['certification'] == "PG-13"]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 17    tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
# 18    tt0120903    0.0  /yGxMIIDSUvaXUjjJuIYZi40Jt3J.jpg
# 40    tt0138818    0.0                               NaN
# 41    tt0138927    0.0  /5f8tJLrFdcgSpqYi7U58GEkoMF1.jpg
# 45    tt0141926    0.0  /2W1AA5qZXJrR7MJXUgqj49JsLYy.jpg
# ...         ...    ...                               ...
# 2238  tt0293416    0.0  /fmlTj7qDrNdfpBMcEfEpnzwpMr0.jpg
# 2288  tt0297024    0.0                               NaN
# 2420  tt0322645    0.0  /aWg40fkUvghFwrCya2fHvAEvjud.jpg
# 2513  tt0832449    0.0  /qgaVJE4SK2qRtggVyRlISKQ1zBE.jpg
# 2517  tt1073223    0.0  /le7N8M4bAM9suFGGTjvYblfmPT8.jpg
#
#                                   belongs_to_collection       budget  \
# 17    {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
# 18    {'id': 748, 'name': 'X-Men Collection', 'poste...   75000000.0
# 40                                                  NaN          0.0
# ...

# %%
df_merged.loc[ df_merged['certification'] == "R"]
# Out:
#         imdb_id  adult                     backdrop_path  \
# 5     tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
# 6     tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 7     tt0119495    0.0                               NaN
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 16    tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# ...         ...    ...                               ...
# 2377  tt0307448    0.0                               NaN
# 2387  tt0311361    0.0  /chTzuvknyHTc0jqjQjGsEjmg5DG.jpg
# 2412  tt0318819    0.0  /z7nc41k7XyfGa2zhOOlfyXeMX4s.jpg
# 2416  tt0321959    0.0  /6S8tSirOcBRmOlh4mFSTrorNwnD.jpg
# 2459  tt0364722    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 5                                                   NaN         0.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 7                                                   NaN         0.0
# ...

# %%
df2 = df_merged[["revenue"]].mean()
print(df2)
# Out:
# revenue    1.094366e+07
# dtype: float64

# %%
data = {'certification' == "R"}

df = pd.DataFrame(df2)

av_column = df.mean(axis=0)
print (av_column)
# Out:
# 0    1.094366e+07
# dtype: float64

# %%
data = {'certification': 'G''PG''PG-13''R'}

df = pd.DataFrame(df2)

av_column = df.mean(axis=0)
print (av_column)
# Out:
# 0    1.094366e+07
# dtype: float64

# %%
df3 = df_merged[["budget"]].mean()
print(df3)
# Out:
# budget    5.191485e+06
# dtype: float64

# %%
d = {'certification': ['G', 'PG', 'PG-13', 'R']}

df = pd.DataFrame(d)

# Display Original dataframe
print("Created Dataframe:\n",df,"\n", df3)

# Calculating mean
df['Mean'] = df.mean(axis=1)

# Display modified DataFrame
print("Modified DataFrame:\n",df, df3)
# Out:
# Created Dataframe:
#    certification
# 0             G
# 1            PG
# 2         PG-13
# 3             R
#  budget    5.191485e+06
# dtype: float64
# Modified DataFrame:
#    certification  Mean
# 0             G   NaN
# 1            PG   NaN
# 2         PG-13   NaN
# 3             R   NaN budget    5.191485e+06
# dtype: float64
# C:\Users\cathe\AppData\Local\Temp\ipykernel_13868\3345998666.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Mean'] = df.mean(axis=1)

# %%
# create a pandas dataframe
scores_df = pd.DataFrame(['certification' ['G', 'PG', 'PG-13', 'R'],
                          "df_merged[ 'revenue' ]" > 0 ])
# display the dataframe
print(scores_df)
print(scores_df.mean(axis=1))
# Out:
# <>:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\cathe\AppData\Local\Temp\ipykernel_13868\1294117254.py:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   scores_df = pd.DataFrame(['certification' ['G', 'PG', 'PG-13', 'R'],
# C:\Users\cathe\AppData\Local\Temp\ipykernel_13868\1294117254.py:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   scores_df = pd.DataFrame(['certification' ['G', 'PG', 'PG-13', 'R'],
# C:\Users\cathe\AppData\Local\Temp\ipykernel_13868\1294117254.py:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   scores_df = pd.DataFrame(['certification' ['G', 'PG', 'PG-13', 'R'],
# ---------------------------------------------------------------------------
# ...
